# %% [markdown]
# # 0 Imports

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

import re

import pandas as pd

from src.suporte import funcoes_suporte as fs

# %% [markdown]
# ## 0.1 Funções Suporte

# %%
fs.jupyter_settings(altura = 10, largura = 12, fonte = 8)
fs.supressao_notacao(casa_decimal = 2)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # 0.2 Load Data

# %%
df = fs.load_pickle('../data/interim/1.descricao.pkl')
df.sample(5)
# Out:
#        invoice_no stock_code                         description  quantity invoice_date  unit_price  customer_id         country
# 451541     575214      21509  COWBOYS AND INDIANS BIRTHDAY CARD         12   2011-11-09        0.42        16751  United Kingdom
# 361509     568346      23263   SET OF 3 WOODEN HEART DECORATIONS         9   2011-09-26        2.46        14096  United Kingdom
# 231521     557270      23298                      SPOTTY BUNTING         2   2011-06-19        4.95        14162  United Kingdom
# 224233     556510      23240   SET OF 4 KNICK KNACK TINS DOILEY          6   2011-06-13        4.15        14911            EIRE
# 370332     569136      23154            SET OF 4 JAM JAR MAGNETS         2   2011-09-30        2.08        15834  United Kingdom

# %% [markdown]
# # 1.0 Tratamento

# %% [markdown]
# ## 1.1 Numerico

# %% [markdown]
# ### 1.1.1 unit_price
#
# Os valores zerados são assumidos como brindes.

# %%
df = df.loc[df['unit_price'] >= 0.04,:]

# %% [markdown]
# ## 1.2 Categórico

# %% [markdown]
# ### 1.2.1 stock_code
#
# Retirar valores indevidos

# %%
df = df.loc[~(df['stock_code'].isin(['POST', 'D', 'C2', 'M', 'BANK CHARGES', 'PADS', 'DOT', 'CRUK']))]

# %% [markdown]
# ### 1.2.2 description
#
# não irei trabalhar com eles agora

# %%
df = df.drop(columns=['description'])

# %% [markdown]
# ### 1.2.3 Country
#
# Retirar paises não identificados e Comunidade europeia, por não ser país

# %%
df = df[~(df['country'].isin(['European Community','Unspecified']))]

# %% [markdown]
# ### 1.3 Separação em 2 DF Compra e Devolução

# %%
df_returns = df.loc[df['quantity'] < 0,:]
df_compras = df.loc[df['quantity'] > 0,:]

# %% [markdown]
# # 2.0 Export DF

# %%
fs.save_pickle(df,"../data/interim/2.all_quantity.pkl")
fs.save_pickle(df_returns,"../data/interim/2.df_returns.pkl")
fs.save_pickle(df_compras,"../data/interim/2.df_compras.pkl")
