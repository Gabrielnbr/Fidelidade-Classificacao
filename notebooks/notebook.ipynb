# %%
import pickle

import pandas as pd
import numpy as np

from src.suporte import funcoes_suporte as fs

# %%
PATH_DATA = "data/raw/data.csv"

df = pd.read_csv(PATH_DATA, encoding_errors="replace")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
categorico, numerico = fs.separacao_categorico_numerico(df)

# %%
fs.estatistica_descritiva(numerico)
# Out:
#     variaveis    minimo   maximo      range         media  mediana  \
# 0    Quantity -80995.00  80995.0  161990.00      9.552250     3.00
# 1   UnitPrice -11062.06  38970.0   50032.06      4.611114     2.08
# 2  CustomerID  12346.00  18287.0    5941.00  15287.690570      NaN
#
#    desvio_padrao      iqr  assimetria       curtosis         cv
# 0     218.080957     9.00   -0.264076  119769.160031  22.830346
# 1      96.759764     2.88  186.506972   59005.719097  20.984053
# 2    1713.598197  2838.00    0.029835      -1.179982   0.112090

# %%
numerico.hist(bins = 30)
# Out:
# array([[<Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'UnitPrice'}>],
#        [<Axes: title={'center': 'CustomerID'}>, <Axes: >]], dtype=object)

# %%
fs.visualizacao_dados_categoricos(categorico)
# Out:
# Atributo: InvoiceNo
# Total de Valores Únicos: 25900
# Total de Valores não Nulos: 541909
# Total de Valores Nulos: 0
# Porcentagem Valores Nulos (%) : 0.00%
#
# ...
